# %% [markdown]
# <a href="https://colab.research.google.com/github/pmehta2612/Glassdoor-EDA-Project/blob/main/Glassdoor_EDA(Exploratory_Data_Analysis)_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# This project involves an exploratory data analysis (EDA) of job postings data from Glassdoor.com (2017-2018) to gain insights into salary trends for various tech job positions. The dataset contains key features such as job title, company size, and job location, allowing for a detailed examination of salary distributions, industry comparisons, and the impact of company attributes on compensation. By analyzing this dataset, the goal is to help job seekers make informed career decisions, assist companies in setting competitive salaries, and provide insights into broader labor market trends.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# [Glassdoor EDA Project](https://github.com/pmehta2612/Glassdoor-EDA-Project)

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# This project aims to analyze salary trends based on job attributes using Exploratory Data Analysis (EDA). The key objectives include:
#
# 1. Understanding salary variations across job positions (e.g., Data Engineer,
# Software Engineer, Data Scientist).
#
# 2. Examining the impact of company size on salary levels.
#
# 3. Analyzing salary differences based on job location.
#
# 4. Whether a predictive model would help to estimate salaries based on job attributes.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# * The first objective is to assist job seekers in making informed career decisions by providing insights into expected salary ranges for various roles.
#
# * The second objective is for employers, helping them set competitive salaries to attract and retain top talent.
#
# * The third objective targets analysts and researchers, offering data-driven insights into salary trends based on industry, experience, and geography.
#
# * The final objective supports recruiters by helping them estimate salaries and ensure fair compensation practices.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd                 # Data Manipulation & Analysis
import numpy as np                  # Numerical Computing
import matplotlib.pyplot as plt     # Data Visualization
import seaborn as sns               # Data Visualization

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
df = pd.read_csv('/content/glassdoor_jobs.csv')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df
# Out:
#      Unnamed: 0                                          Job Title  \
# 0             0                                     Data Scientist
# 1             1                          Healthcare Data Scientist
# 2             2                                     Data Scientist
# 3             3                                     Data Scientist
# 4             4                                     Data Scientist
# ..          ...                                                ...
# 951         951                               Senior Data Engineer
# 952         952  Project Scientist - Auton Lab, Robotics Institute
# 953         953                               Data Science Manager
# 954         954                                      Data Engineer
# 955         955          Research Scientist – Security and Privacy
#
#                  Salary Estimate  \
# 0     $53K-$91K (Glassdoor est.)
# 1    $63K-$112K (Glassdoor est.)
# 2     $80K-$90K (Glassdoor est.)
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
print("Number of Rows =", df.shape[0])        # Row Count
print("Number of Columns =", df.shape[1])     # Column Count
# Out:
# Number of Rows = 956
# Number of Columns = 15

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 956 entries, 0 to 955
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         956 non-null    int64
#  1   Job Title          956 non-null    object
#  2   Salary Estimate    956 non-null    object
#  3   Job Description    956 non-null    object
#  4   Rating             956 non-null    float64
#  5   Company Name       956 non-null    object
#  6   Location           956 non-null    object
#  7   Headquarters       956 non-null    object
#  8   Size               956 non-null    object
#  9   Founded            956 non-null    int64
#  10  Type of ownership  956 non-null    object
#  11  Industry           956 non-null    object
#  12  Sector             956 non-null    object
#  13  Revenue            956 non-null    object
#  14  Competitors        956 non-null    object
# dtypes: float64(1), int64(2), object(12)
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
print("Are there any Duplicates in Dataset =",df.duplicated().any())
print("Number of Duplicates in Dataset = ",df.duplicated().sum())        # Duplicate count
# Out:
# Are there any Duplicates in Dataset = False
# Number of Duplicates in Dataset =  0

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
df.isnull().sum()
# Out:
# Unnamed: 0           0
# Job Title            0
# Salary Estimate      0
# Job Description      0
# Rating               0
# Company Name         0
# Location             0
# Headquarters         0
# Size                 0
# Founded              0
# Type of ownership    0
# Industry             0
# Sector               0
# Revenue              0
# Competitors          0
# dtype: int64

# %%
# Visualizing the missing values
# Create heatmap
plt.figure(figsize= (10,6))
sns.heatmap(data= df.isnull(), cmap = 'coolwarm', yticklabels= False)
# Show plot
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# The glassdoor jobs dataset contains job postings from Glassdoor.com from 2017-18. The dataset contains total 956 records which includes key features such as job title, salary estimate, job description, rating, company name, location, headquarters, size, founded, type of ownership, industry, sector, revenue, competitors. The dataset does not contain any duplicate entries and even no missing/null values are present ensuring complete data for analysis.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns
# Out:
# Index(['Unnamed: 0', 'Job Title', 'Salary Estimate', 'Job Description',
#        'Rating', 'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors'],
#       dtype='object')

# %%
# Dataset Describe
df.describe()
# Out:
#        Unnamed: 0      Rating      Founded
# count  956.000000  956.000000   956.000000
# mean   477.500000    3.601255  1774.605649
# std    276.117729    1.067619   598.942517
# min      0.000000   -1.000000    -1.000000
# 25%    238.750000    3.300000  1937.000000
# 50%    477.500000    3.800000  1992.000000
# 75%    716.250000    4.200000  2008.000000
# max    955.000000    5.000000  2019.000000

# %% [markdown]
# ### Variables Description

# %% [markdown]
# 1. **Job Title -** The title of the job posting which helps to categorize roles.
# 2. Salary Estimate - Contains the salary range for the particular job which contains the salary given for the job role.
# 3. **Job Description -** Contains full description of the job.
# 4. **Rating -** It includes rating of that post which reflects the reputation and work environment.
# 5.  **Company Name -** It contains the company's name which is hiring.
# 6. **Location —** This includes the company's geographic location, which examines the salary variation across different regions.
# 7. **Headquarters -** This includes the headquarters of the company.
# 8. **Size -** This includes the total employees in that company which helps to analyze the impact on salary.
# 9. **Founded -** This includes the year when the company came into existence which helps to indicate its establishment and stability.
# 10. **Type of Ownership -** Describes the ownership i.e private/public/non-profit etc.
# 11. **Industry & Sector -** Describe the fields where the applicant will work.
# 12. **Revenue -** Total revenue of the company
# 13. **Competitors -** Includes competitors in the market which affects the job demand and salaries.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
df.nunique()
# Out:
# Unnamed: 0           956
# Job Title            328
# Salary Estimate      417
# Job Description      596
# Rating                32
# Company Name         448
# Location             237
# Headquarters         235
# Size                   9
# Founded              109
# Type of ownership     13
# Industry              63
# Sector                25
# Revenue               14
# Competitors          149
# dtype: int64

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.

# 1. Dropping unnecessary columns
df.drop(columns = 'Unnamed: 0', inplace= True)

# 2. Salary Estimate-
# Filtering out records with salary < 0
df = df[df['Salary Estimate']!= '-1']

# Splitting the Salary Estimate Column and view only the salary ranges
df['Salary Estimate'] = df['Salary Estimate'].apply(lambda x: x.split('(')[0])

# Removing the $ and K symbols from salary estimate column to view only salary range values
df['Salary Estimate']= df['Salary Estimate'].apply(lambda x: x.replace('$','').replace('K',''))

# Creating new column which stores all the salaries paid on hourly basis
df['Hourly'] = df['Salary Estimate'].apply(lambda x: 1 if 'per hour' in x.lower() else 0)

# Creating new column which stores the records of all the employer provided salaries
df['Employer_Provided'] = df['Salary Estimate'].apply(lambda x: 1 if 'employer provided salary:' in x.lower() else 0)

# Removing the text i.e per hour, employer provided salary containing in salary estimate column
df['Salary Estimate'] = df['Salary Estimate'].apply(lambda x: x.lower().replace('per hour','').replace('employer provided salary:',''))

# Extracting minimum and maximum salary
df['Min_Salary'] = df['Salary Estimate'].apply(lambda x: int(x.split('-')[0]))
df['Max_Salary'] = df['Salary Estimate'].apply(lambda x: int(x.split('-')[1]))
# Calculating average salary from minimum and maximum values
df['Average_Salary'] = (df['Min_Salary'] + df['Max_Salary'])/2

# Ensuring salaries are in full values
df['Min_Salary'] = df['Min_Salary'] * 1000
df['Max_Salary'] = df['Max_Salary'] * 1000

# Converting all the salaries which are hourly basis into annual basis
df['Min_Salary'] = df.apply(lambda x: x.Min_Salary*40*52 if x['Hourly']== 1 else x.Min_Salary, axis = 1)
df['Max_Salary'] = df.apply(lambda x: x.Max_Salary*40*52 if x['Hourly']== 1 else x.Max_Salary, axis = 1)

# 3. Company Name-
# Extracting only Company Name part
df['Company_Text'] = df.apply(lambda x: x['Company Name'] if x['Rating'] < 0 else x['Company Name'][:-4], axis=1)

# 4. Location
# Finding State where company has physical existence
df['Job_State'] = df['Location'].apply(lambda x: x.split(',')[1])    # Splitting the values in location and extracting the state part

# Finding Records which have job location is in headquarters
df['Same_State'] = df.apply(lambda x: 1 if x['Location'] == x['Headquarters'] else 0, axis = 1)

# 5. Founded-
# Finding the company age from current year (number of years company existing)
df['Company_Age'] = df['Founded'].apply(lambda x: x if x < 1 else 2025-x)

# 6. Job Description-
# Extracting skills from job description
skills = ['Python', 'SQL', 'Tableau', 'Excel', 'Machine Learning', 'Deep Learning', 'Power BI', 'R Studio', 'AWS']
# Create a new column for each skill
for skill in skills:
    df[skill] = df['Job Description'].str.contains(skill, case=False, na=False).astype(int)

# 7. Job Title-
# Extracting consistent job title
def title_simplifier(title):
  if 'data scientist' in title.lower():
    return 'Data Scientist'
  elif 'data engineer' in title.lower():
    return 'Data Engineer'
  elif 'analyst' in title.lower():
    return 'Analyst'
  elif 'machine learning' in title.lower():
    return 'Machine Learning'
  elif 'manager' in title.lower():
    return 'Manager'
  elif 'director' in title.lower():
    return 'Director'
  else:
    return 'Others'
# Applying the function
df['Job_Simp'] = df['Job Title'].apply(title_simplifier)

# Extracting seniority level from job title
def seniority_level(title):
  if 'sr' in title.lower() or 'senior' in title.lower() or 'sr.' in title.lower() or 'lead' in title.lower() or 'principal' in title.lower():
    return 'Senior'
  elif 'jr' in title.lower() or 'jr.' in title.lower():
    return 'Junior'
  else:
    return 'NA'
# Applying the function
df['Seniority'] = df['Job Title'].apply(seniority_level)

# 8. Competitors-
# Calculating number of competitors for each company
df['Num_Competitors'] = df['Competitors'].apply(lambda x: len(x.split(',') if x!= -1 else 0))

# View all the columns of the dataset
pd.set_option('display.max_columns', None)
# View top 5 records of the dataset
df.head(5)
# Out:
#                    Job Title Salary Estimate  \
# 0             Data Scientist          53-91
# 1  Healthcare Data Scientist         63-112
# 2             Data Scientist          80-90
# 3             Data Scientist          56-97
# 4             Data Scientist         86-143
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#                                  Company Name         Location  \
# 0                      Tecolote Research\n3.8  Albuquerque, NM
# 1  University of Maryland Medical System\n3.4    Linthicum, MD
# 2                                KnowBe4\n4.8   Clearwater, FL
# 3                                   PNNL\n3.8     Richland, WA
# ...

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# 1. **Dropped Unnecessary Columns -** Removed unnecessary column (Unnamed: 0) which was not necessary for the analysis so we removed the column.
# ---
# 2. **Salary Estimate -**
# *  Filtered out the records where salary estimate not equal(!=) -1 and it was found that there were 214 records that had a Salary Estimate of -1 (missing data/unavailable salary information) and were removed to ensure accurate salary analysis.
# *  Removed "(Glassdoor est.)" from the Salary Estimate column by splitting values
# using the '(' delimiter and keeping only the salary range.
# *  Extracted numeric salary values from the salary range, ensuring clean numerical data for analysis.
# *  Created separate columns to identify hourly paid salaries and employer-provided salaries. It was found that 24 employees were paid on an hourly basis, and 17 employees had employer-provided salaries.
# *  There were text i.e per hour, employer provided salary which was removed.
# *  Extracted minimum and maximum salary values from the salary range.Calculated the average salary for better salary insights.It is found that the minimum salary paid is 10K, while the maximum salary paid is 306K.
# *  Converted salary values into full numeric format for accurate analysis and also converted hourly salaries into annual salaries for consistency.
# ---
# 3. **Company Name -** Cleaned the Company Name column by removing ratings, extracting only the company name using slicing.
# ---
# 4. **Location -**
# *  Split the Location column to extract the primary company location where it has a physical presence. Found that New York, NY has the highest job openings.
# *  Identified records where the job location is at company headquarters. It was found that there were total 414 companies.
# ---
# 5. **Founded -** Calculated the age of the company based on the number of years since its establishment. Found that Sotheby’s is the oldest company, with an age of 281 years.
# ---
# 6. **Job Description -** Extracted skills from the job description and identified the most in-demand skills are Python, SQL, Excel, and Machine Learning (ML).
# ---
# 7. **Job Title -**
# *  Extracted consistent job titles and found six distinct job titles, with Data Scientist being the most common.
# *  Extracted seniority levels from job titles. Majority of job titles did not specify seniority. Senior-level roles were significantly more common than junior roles, indicating a higher demand for experienced professionals.
# ---
# 8. **Competitors -** Calculated the number of competitors for each company and found that C Space has the highest number of competitors, with 4.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
# Visualization style
plt.style.use('Solarize_Light2')
# Create histogram
plt.figure(figsize=(12, 5))
sns.histplot(df['Average_Salary'], bins=30, kde=True, color='red')
# Add title and label
plt.title("Salary Distribution")
plt.xlabel("Average Salary")
plt.ylabel("Frequency")
# Show plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A histogram with KDE (Kernel Density Estimation) was chosen because:
# *  A histogram helps visualize the distribution of salary values, showing the frequency of salary ranges.
# *  The KDE curve provides a smooth approximation of the distribution, helping to identify skewness, peaks, and spread more effectively.
# *  This chart is ideal for univariate analysis, where we focus on understanding a single variable’s distribution.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the histogram and KDE plot:
# *  The distribution is right-skewed, it indicates that most jobs have lower salaries, with fewer high-paying positions.
# *  The spread of salaries helps us understand salary disparities across different roles.
# *  The presence of outliers (extremely high or low salaries) can be seen from extended tails in the KDE plot.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these gained insights can help creating a positive business impact in multiple ways:
# * Companies able to adjust their salary structures to stay competitive.
# * If salaries are too low, attracting skilled professionals may be difficult.
# * Understanding salary distributions helps in allocating HR budgets effectively.
#
# Yes, there are some insights which lead to negative growth which are:
# * The salaries are right-skewed, it may create pay disparity, leading to dissatisfaction among employees.
# * We can see from the chart majority of the salaries fall in lower range which might suggest lack of growth opportunities, leading to higher attrition.
# * If a few roles have significantly high salaries compared to others, it may cause internal dissatisfaction and budget constraints for companies.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
# Create countplot
plt.figure(figsize=(12, 5))
ax = sns.countplot(x=df['Job_Simp'], order=df['Job_Simp'].value_counts().index, hue= df['Job_Simp'], legend= False, palette="viridis")
# Adding data labels
for p in ax.patches:
    ax.annotate(f'{int(p.get_height())}',  # Text (Count Value)
                (p.get_x() + p.get_width() / 2, p.get_height()),  # X, Y Position
                ha='center', va='bottom', fontsize=9, fontweight='bold', color='black')  # Styling
# Add title and label
plt.title("Job Position Distribution")
plt.xlabel("Job Title")
plt.ylabel("Count")
# Show plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A countplot was chosen because:
# * It helps visualize the frequency of different job positions in the dataset.
# * This is the best choice for categorical data (e.g., job titles), allowing us to compare the number of job postings for each role.
# * The order of job positions (sorted by count) gives a clear ranking of the most and least common jobs.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the countplot:
# *  Data Scientist job position are most in demand as it has the highest count which indicates company is actively hiring for that position.
# * Director job position has lowest count which indicates less frequently hired position.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights are highly valuable for businesses:
# * It will help the companies understand which roles are in demand and align their recruitment strategies accordingly.
# * Job seekers can focus on upskilling in high-demand roles to increase employability.
# * Companies can allocate hiring budgets more effectively by focusing on roles with high demand.
#
# Yes, potential negative impacts include:
# * If one job position dominates, competition among candidates may increase, making it harder for job seekers to get hired.
# * If a job position has very few postings for example ML positions, professionals in that field might struggle to find employment.
# * If previously high-demand roles are now low in count, it could indicate an industry shift, requiring professionals to reskill or change careers.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
# Count occurrences of each company size
df = df[df['Size'] != '-1']
company_size_counts = df['Size'].value_counts()
# Plot the pie chart
plt.figure(figsize=(9, 5))
plt.pie(company_size_counts, labels=company_size_counts.index, autopct='%1.1f%%',
                                   colors=plt.cm.Paired.colors, startangle=140)
# Add a legend outside the pie chart
plt.legend(company_size_counts.index, title="Company Size", loc="center left", bbox_to_anchor=(1.5, 0.3))

# Title of the chart
plt.title("Company Size Distribution")
# Adjust layout to prevent overlap
plt.tight_layout()
# Show plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pie chart is useful for:
# * Showing proportions of different company sizes, making it easy to compare how frequently each size category appears.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the countplot:
# * The largest proportion of job postings comes from companies with 1001-5000 employees.
# * Companies with 501-1000 employees and 10000+ employees also have significant job postings.
# * Smaller companies (1-50, 51-200) contribute less to job postings compared to larger firms.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, The insights can help to create a positive business impact by:
# * Understanding which company sizes post the most jobs helps job seekers target the right employers.
# * Businesses can benchmark themselves against competitors and adjust hiring strategies accordingly.
#
# Yes, the company size distribution pie chart may indicate potential challenges leading to negative growth:
# * If smaller companies (e.g., 1-50 employees) have a lower count, it could mean they struggle with growth, funding, or talent acquisition, leading to higher turnover and lower stability.
# * Mid-sized companies show significant numbers, they may face scalability issues, such as operational inefficiencies, higher employee attrition, or salary constraints compared to larger firms.
# * If fewer large companies exist, it might suggest market consolidation, where only a few firms dominate, making it difficult for new companies to scale up.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
# Create bar plot
plt.figure(figsize=(14, 6))
top_locations = df['Location'].value_counts().nlargest(10)  # Top 10 locations
ax = sns.barplot(x=top_locations.index, y=top_locations.values, hue = top_locations.index)
# Add data labels
for p in ax.patches:
    ax.annotate(f'{int(p.get_height())}',  # Text (Count Value)
                (p.get_x() + p.get_width() / 2, p.get_height()),  # X, Y Position
                ha='center', va='bottom', fontsize=9, fontweight='bold', color='black')  # Styling
# Add title and label
plt.title("Top 10 Job Locations")
plt.xlabel("Location")
plt.ylabel("Count")
plt.xticks(rotation=40)
# Show plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar plot is the best way to compare the number of job postings across different locations because:
# * It effectively shows differences in job demand.
# * The ranking of cities is clear.
# * Helps to identify which locations have the highest job demand.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * New York NY , San Francisco CA , and Cambridge MA has the highest job postings in the dataset.
# * Tech and finance hubs (San Francisco & New York) are leading in job demand, indicating high industry growth.
# * Cambridge’s strong hiring presence suggests biotech, research, and education sectors are actively recruiting.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. These insights create a positive business impact in following ways:
# * Job seekers can focus their applications in top hiring cities to increase their chances.
# * Companies can analyze hiring trends and adjust recruitment strategies based on demand in specific cities.
# * Businesses looking to expand may consider these cities due to their strong job markets.
#
# Some of the insights which can lead to negative growth are:
# * Smaller cities may have fewer opportunities, making it harder for professionals in those areas to find jobs.
# * Hiring concentration in just a few cities could lead to high cost of living, job market saturation, and competition in those locations.
# * Smaller businesses outside these locations may struggle to attract top talent, as candidates prefer relocating to job hubs.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
# Create box plot
plt.figure(figsize=(14, 6))
sns.boxplot(x=df['Job_Simp'], y=df['Average_Salary'], hue = df['Job_Simp'], palette="Set2")
# Add title and label
plt.title("Salary Variation by Job Position")
plt.xlabel("Job Title")
plt.ylabel("Average Salary")
plt.xticks(rotation=0)
# Show plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A box plot also known as box and whisker plot is ideal for analyzing salary variation across different job positions because it:
# * Shows the distribution of salaries for each role.
# * Highlights median, quartiles, and outliers to understand salary spread.
# * Helps compare salary ranges across job positions.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the box plot:
# * The median salary varies significantly across different job positions, indicating differences in pay levels.
# * Some job titles have a wider interquartile range (IQR), meaning salary variation is higher within that role.
# * Positions like Data Scientist, Machine Learning, and Data Engineer likely have higher median salaries.
# * Roles such as Analyst might have lower median salaries compared to other roles.
# * Wider boxes indicate greater salary variation, meaning salaries for that job title fluctuate significantly.
# * Roles which have many individual points outside the whiskers i.e Data Scientist, ML, Data Engineer, it suggests that some employees earn significantly higher or lower than the majority.
# * Senior or managerial roles might have higher outliers due to experience and bonuses.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes! The insights can:
# * Help job seekers understand salary expectations for different roles.
# * Assist companies in setting competitive salaries based on the industry trend.
# * Enable HR teams to analyze if they are paying employees fairly.
#
# Some of the insights which can lead to negative growth are:
# * There are few job positions that have low median salaries compared to the market, which may lead to employee dissatisfaction and higher attrition rates.
# * Some roles have higher salary variation (large interquartile range), which may indicate pay inequality, which could lead to employee dissatisfaction.
# * Outliers may suggest unfair compensation practices, where some employees are significantly underpaid or overpaid for the same job.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
# Create violin plot
plt.figure(figsize=(14, 6))
sns.violinplot(x=df['Size'], y=df['Average_Salary'], hue = df['Size'], palette="deep")
# Add title and label
plt.title("Impact of Company Size on Salary")
plt.xlabel("Company Size")
plt.ylabel("Average Salary")
plt.xticks(rotation=45)
# Show plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A violin plot is a great choice for analyzing salary distribution across different company sizes because:
# * It combines a box plot and a density plot, giving a deeper insight into salary distribution.
# * Unlike a box plot, it shows the full distribution shape, including peaks, variations, and outliers.
# * It helps identify whether salaries are normally distributed or skewed for different company sizes.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Company size (1001-5000 employees) has the highest salary distribution. Therefore, the salaries for this category appear to be more widely spread, indicating a higher variation in pay.
# * This may suggest that larger mid-sized companies offer competitive salaries.
# * Companies with 501-1000 employees have a slightly lower but still competitive salary range, as the density of that chart shows a strong median salary but with a more concentrated spread.
# * Company with the size of 10,000+ employees have high salaries but with a lower variation. This indicates that large enterprises offer stable, standardized salaries with fewer extreme variations.
# * Smaller companies (e.g., 1-50, 51-200 employees) have lower salary distributions. The peak density in these groups is lower compared to larger companies, suggesting that smaller firms pay less on average.
# * The spread of salaries varies significantly between company sizes. Some company sizes show more variability in salaries, meaning pay depends on specific roles within those firms.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights can drive better business decisions:
# * Job seekers can target larger companies (10000+ employees) if they want higher salary potential.
# * Companies can benchmark salaries against competitors based on company size to attract talent.
# * HR teams can use this data to adjust salary structures based on industry trends.
#
# Some of the insights which can lead to negative growth are:
# * Smaller companies may struggle to attract top talent due to lower salaries, leading to talent retention issues.
# * If large firms offer fixed salary bands, employees might leave for startups where growth potential is higher.
# * Higher salary variations in mid-sized companies (501-5000 employees) could indicate pay inequality, leading to dissatisfaction among employees.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
# Group by Location to get the average salary
avg_salary_by_location = df[df['Location'].isin(top_locations.index)].groupby('Location')['Average_Salary'].mean().reset_index()

# Sorting locations for better visualization
avg_salary_by_location = avg_salary_by_location.sort_values(by='Average_Salary', ascending=False)

# Creating the bar chart
plt.figure(figsize=(14, 6))
colors = plt.cm.Accent.colors[:len(avg_salary_by_location)]  # Using Set2 (light color palette)
bars = plt.barh(avg_salary_by_location['Location'], avg_salary_by_location['Average_Salary'], color=colors)

# Adding data labels
for bar in bars:
    plt.text(bar.get_width() + 2,  # Offset text to the right of the bar
             bar.get_y() + bar.get_height()/2,
             f"{int(bar.get_width())}",  # Display whole number
             ha='left', va='center', fontsize=10, fontweight='bold')

# Titles and labels
plt.title("Average Salary by Location (Top 10)")
plt.xlabel("Location")
plt.ylabel("Average Salary")
plt.xticks(rotation=45)
# Show plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# For this analysis, bar chart is chosen because:
# * A bar chart is ideal for comparing average salaries across different locations.
# * It allows for an easy visual comparison of how salaries differ across various locations.
# * Since location is a categorical variable, a bar chart is a clear and effective choice.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Some of the insights found from the chart are:
# * San Jose, San Francisco, and Chicago have the highest average salaries.
# * Other locations have comparatively lower salaries.
# * The chart helps identify locations where salaries are higher, possibly due to the cost of living, demand for jobs, or company presence in those areas.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. These insights will create a positive business impact as:
# * Businesses can understand salary trends across different locations and adjust their hiring strategies accordingly.
# * Helps in budgeting salary expectations based on location.
# * Useful for job seekers to identify the best locations for higher salaries.
#
# Some of the insights which can lead to negative growth are:
# * If salaries are too high in certain locations, businesses might struggle to attract talent in lower-paying areas.
# * Locations with lower average salaries might indicate a lack of high-paying job opportunities, leading to talent migration.
# * Companies operating in low-salary regions might struggle to retain skilled employees, affecting growth.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
# Create box plot
plt.figure(figsize=(14, 6))
sns.boxplot(x=df['Python'], y=df['Average_Salary'], hue = df['Python'], palette="pastel", legend= False)
# Add Title and Label
plt.title(f"Impact of Python on Salary")
plt.xlabel('Python')
plt.ylabel("Average Salary")
# Show plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * A box plot is used to compare salary distributions for jobs requiring Python vs. those that do not.
# * It helps visualize the spread of salaries, median salary, and presence of outliers.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * The median salary for jobs requiring Python is higher than those that do not require it.
# * The salary range is wider for Python-related jobs, indicating higher earning potential.
# * There may be outliers, suggesting some high-paying jobs for Python-related roles.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the gained insights can help creating a positive business impact as:
# * Helps companies justify higher salary offers for Python-skilled candidates.
# * Encourages professionals to learn Python to increase earning potential.
#
# Some of the insights which can lead to negative impact are:
# * If Python-based jobs are high-paying but fewer, it could lead to higher competition and skill saturation.
# * Companies not offering competitive salaries for Python roles may struggle to attract skilled candidates.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
# Create scatterplot
plt.figure(figsize=(12, 6))
sns.scatterplot(x=df['Rating'], y=df['Average_Salary'], alpha=0.6, color='red')
# Add title and label
plt.title("Company Rating vs Salary")
plt.xlabel("Company Rating")
plt.ylabel("Average Salary")
# Show plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A scatter plot is used:
# * To analyze the relationship between company rating and average salary.
# * It helps identify trends, correlations, and outliers in salary distribution based on ratings.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * The data points seem widely scattered, indicating no strong correlation between company rating and salary.
# * High-rated companies do not always offer the highest salaries.
# * Some low-rated companies still offer competitive salaries.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the gained insights will help to create a positive business impact by:
# * Helping the job seekers to understand that higher company ratings do not guarantee higher salaries.
# * Companies can strategically balance salaries with other factors like work culture and benefits.
#
# Some of the insights which can lead to negative growth are:
# * Top-rated companies may struggle to attract talent if their salary offerings are not competitive.
# * Employees may prioritize pay over company culture, leading to higher turnover rates.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
# Create box plot
plt.figure(figsize=(16, 6))
sns.boxplot(x=df['Type of ownership'], y=df['Average_Salary'], hue = df['Type of ownership'],  palette="Set2")
# Add title and label
plt.title("Impact of Type of Ownership on Salary")
plt.xlabel("Type of Ownership")
plt.ylabel("Average Salary")
plt.xticks(rotation=45)
# Show plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A box plot is suitable for:
# * Comparing salary distributions across different types of ownership.
# * It shows median salary, quartiles, and outliers, helping in understanding variations.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Privately-held and Public companies show a wider salary range compared to others.
# * Government and Non-Profit organizations generally have lower salary variations.
# * Some ownership types have outliers (Privately-held companies), indicating exceptionally high or low salaries.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes! Gained insights will help creating a positive business impact as:
# * It helps the job seekers to understand salary expectations across different ownership types.
# * Companies can benchmark their salary structures to remain competitive.
#
# Insights which can lead to negative growth are:
# * Lower salaries in specific ownership types (e.g., non-profits) may struggle to attract top talent.
# * High salary variability in private companies may indicate lack of standardization in pay scales.

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code
# Create violin plot
plt.figure(figsize=(14, 6))
sns.violinplot(x=df['Revenue'], y=df['Average_Salary'], hue = df['Revenue'], palette="Set3")
# Add title and label
plt.title("Impact of Revenue on Salary")
plt.xlabel("Revenue")
plt.ylabel("Average Salary")
plt.xticks(rotation=45)
# Show plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A violin plot is useful for:
# * Understanding both distribution and density of salary across different revenue categories.
# * It shows median salaries, spread of salaries, and density of data points more effectively than a box plot.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Companies with higher revenue tend to have higher salary distributions.
# * Smaller revenue companies show higher salary variability, indicating inconsistent pay scales.
# * Outliers are visible, showing some low-paying roles even in high-revenue companies.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, The insights create a positive business impact by:
# * Helping job seekers align salary expectations based on company revenue.
# * Employers can compare salary distributions with competitors to stay competitive.
#
# Insights which can lead to negative growth are:
# * Companies with high revenue but low salaries may struggle with talent retention.
# * Salary inconsistency in smaller revenue companies may indicate unstable financial conditions.

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code
# Calculate average salary per sector
sector_salary = df.groupby("Sector")["Average_Salary"].mean().sort_values(ascending=False)

# Create bar plot
plt.figure(figsize=(16, 6))
bars = plt.bar(sector_salary.index, sector_salary.values, color="red", width = 0.7)

# Add data labels
for bar in bars:
    plt.text(bar.get_x() + bar.get_width()/2, bar.get_height(), f'{int(bar.get_height())}',
             ha='center', va='bottom', fontsize=10)
# Add title and label
plt.title("Impact of Sector on Salary")
plt.xlabel("Sector")
plt.ylabel("Average Salary")
plt.xticks(rotation=45, ha='right')
# Show plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar plot is useful for
# * Comparing average salaries across different sectors.
# * It makes it easy to visually compare salary levels for each sector.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Some sectors such as Media, Information Technology and Acccounting & Legal have significantly higher average salaries compared to others.
# * The salary gap between top-paying and low-paying sectors is clearly visible.
# * The lowest-paying sectors such as construction, repair & maintenance, Arts, Entertainment & Recreation may have less competitive salary structures.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, Some of the positive business impactful insights are:
# * Helps job seekers target high-paying sectors.
# * Businesses can adjust their salary structures to attract and retain talent.
#
# Some negative growth insights are:
# * Low salaries in certain sectors may lead to high employee turnover.
# * Large salary differences between sectors may cause talent migration to higher-paying industries.

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code
# Create box plot
plt.figure(figsize=(12, 6))
sns.boxplot(x=df['Size'], y=df['Rating'], hue = df['Size'], palette="Set2")
# Add title and label
plt.title("Relationship Between Company Rating and Company Size")
plt.xlabel("Company Size")
plt.ylabel("Company Rating")
plt.xticks(rotation=45)
# Show plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * The box plot effectively visualizes distribution, median, variability, and outliers of ratings for different company sizes.
# * It helps compare how rating consistency changes across company sizes.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Larger companies (10,000+ employees) tend to have higher and more stable ratings.
# * Smaller companies (51-200 employees) have the most variation in ratings, meaning employee satisfaction is inconsistent.
# * Mid-sized companies (501-1000 employees) have a few outliers with very low ratings, suggesting potential management or work culture issues.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights can help:
# * Job seekers understand how company size may impact employee satisfaction.
# * Employers can improve company policies by learning from the rating trends in different company sizes.
#
# Insights which can lead to negative growth are:
# * If mid-sized companies have lower median ratings and more outliers, it could indicate retention or management issues.
# * Smaller companies having a wide rating range may struggle with employee satisfaction consistency, leading to higher turnover.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
# Create heatmap
plt.figure(figsize=(12, 6))
sns.heatmap(df[['Rating','Founded','Min_Salary','Max_Salary','Average_Salary','Same_State','Company_Age','Python','SQL',
                'Tableau','Excel','Machine Learning','Deep Learning','Power BI','R Studio','AWS','Num_Competitors']].corr(numeric_only= True),
            annot=True, cmap="coolwarm", fmt=".2f", linewidths= 0.5)
# Add title
plt.title("Correlation Heatmap")
# Show plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The heatmap helps to:
# * Effectively visualize the correlation between multiple numerical variables in a single view.
# * It helps identify which factors influence salary the most and which ones have little to no impact

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Company Age and Salary might show a low or no correlation, meaning company age doesn't significantly impact salaries.
# * Rating and Salary have a low or weak positive correlation, meaning higher-rated companies may not necessarily pay higher salaries.
# * Python and Machine Learning show a higher correlation with salary, it indicates that advanced technical skills are more valued in higher-paying jobs.
# * Number of Competitors might show low correlation with salary, meaning industries with high competition may pay slightly lower.
# * Company Age and Rating have a weak or positive correlation, meaning older companies might be rated slightly higher due to stability.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code
# Create Pair Plot
sns.pairplot(df[['Average_Salary', 'Company_Age', 'Rating','Num_Competitors']])
# Add title
plt.suptitle("Pairplot of Key Salary Influencing Factors", fontsize=16, y=1.02)  # Adjust y for spacing
# Show Plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Pairplot is useful for:
# * Identifying patterns, trends, and relationships between multiple numerical variables at once.
# * It helps check linear relationships, clustering, and potential outliers.
# * The diagonal histograms show distribution, while the scatter plots show correlations between variables

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * **Average Salary vs. Rating:** Likely weak or no correlation, meaning company rating does not significantly impact salary.
# * **Average Salary vs. Company Age:** It shows a weak or slightly positive correlation, indicating that older companies may pay slightly higher salaries but not significantly.
# * **Average Salary vs. Number of Competitors:** A trend appears, which indicate higher competition may slightly lower salaries.
# * **Rating vs. Company Age:** A positive trend is seen, means older companies might have slightly higher ratings.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# * **Optimize Salary Strategies:** Offer competitive pay based on location, company size, and industry trends.
# * **Focus on High-Demand Skills:** Encourage Python, SQL, and Machine Learning expertise for better salary growth.
# * **Location-Based Adjustments:** Consider salary benchmarks for top-paying locations to attract talent.
# * **Leverage Company Growth:** Use company size and revenue as a strong factor in salary decisions.
# * **Competitive Analysis:** Monitor competitors' salary structures to remain competitive in hiring.
#
# These recommendations will help businesses attract top talent, reduce attrition, and optimize salary structures for long-term success.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# This Glassdoor EDA project provides a comprehensive analysis of salary trends in the tech industry, uncovering key insights that can help job seekers, employers, and recruiters. By examining salary distributions across different job roles, company sizes, and locations, this analysis helps professionals make data-driven career decisions.
# Additionally, the study highlights important trends that companies can use to refine their compensation strategies and remain competitive in the job market. Future work can focus on building predictive models to estimate salaries based on job attributes, further enhancing the ability to provide actionable salary insights.
# This project enhance the value of data-driven decision-making in understanding labor market trends and ensuring fair compensation practices across industries.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
